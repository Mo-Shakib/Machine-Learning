# %%
print("Hello")
# Out:
# Hello

# %%
import random
arr = []

for i in range(1000):
    arr.append(random.randint(0,100))

print(arr)
# Out:
# [19, 85, 62, 27, 70, 3, 37, 20, 52, 31, 63, 70, 68, 48, 26, 56, 27, 19, 69, 24, 98, 55, 70, 88, 39, 84, 8, 41, 42, 27, 73, 71, 39, 89, 24, 23, 72, 80, 20, 90, 33, 38, 33, 15, 54, 30, 100, 39, 70, 41, 64, 22, 9, 14, 90, 26, 28, 39, 80, 92, 98, 0, 64, 32, 49, 23, 2, 1, 46, 10, 69, 0, 88, 53, 83, 55, 94, 14, 14, 76, 25, 76, 80, 1, 64, 17, 18, 49, 59, 44, 88, 78, 78, 76, 8, 40, 44, 82, 25, 65, 100, 63, 78, 3, 59, 77, 84, 67, 5, 40, 49, 100, 25, 56, 52, 55, 2, 75, 87, 14, 64, 34, 84, 83, 91, 11, 92, 61, 50, 91, 2, 16, 91, 64, 68, 50, 92, 90, 51, 84, 16, 58, 63, 73, 30, 60, 58, 53, 29, 27, 43, 83, 78, 73, 68, 54, 17, 5, 39, 68, 94, 100, 54, 37, 49, 8, 53, 22, 82, 29, 100, 54, 17, 61, 95, 48, 43, 63, 51, 90, 60, 83, 8, 7, 71, 57, 25, 35, 41, 79, 20, 18, 24, 92, 86, 8, 57, 69, 93, 40, 74, 5, 73, 3, 16, 63, 45, 17, 89, 45, 7, 32, 35, 6, 58, 74, 38, 80, 39, 76, 68, 76, 13, 72, 27, 10, 53, 33, 47, 53, 17, 79, 94, 86, 67, 90, 27, 36, 40, 100, 51, 82, 35, 91, 90, 31, 47, 48, 18, 86, 22, 54, 43, 5
# ...

# %%
print('Max',max(arr))
print('Min',min(arr))
# Out:
# Max 100
# Min 0

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(arr)
plt.show()

# %%
arr = sorted(arr)
plt.plot(arr)
plt.show()
